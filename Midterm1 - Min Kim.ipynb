# 583452                1        -73.989288        40.730148         -73.983131
# 583453                5        -73.990097        40.738583         -73.991425
# 583454                1        -73.967110        40.762661         -73.976532
# 583455                1        -73.986458        40.759899         -73.974052
# 583456                1        -73.947845        40.790138         -73.950523
# 583457                2        -73.985802        40.753136         -73.981735
#
#         dropoff_latitude store_and_fwd_flag  trip_duration
# 0              40.782879                  N           2170
# 1              40.753986                  N            808
# 2              40.747150                  N           3787
# 3              40.739731                  N            679
# 4              40.809151                  N           2791
# 5              40.778717                  N           1103
# 6              40.742901                  N            364
# 7              40.787407                  N            235
# 8              40.719486                  N            376
# 9              40.773663                  N           1764
# 10             40.774620                  N            204
# 11             40.756447                  N            214
# 12             40.759495                  N           1249
# 13             40.674191                  N            438
# 14             40.749725                  N           1609
# 15             40.762779                  N            714
# 16             40.738911                  N            714
# 17             40.744942                  N            358
# 18             40.762669                  N           1623
# 19             40.764408                  N           1343
# 20             40.784756                  N            352
# 21             40.763870                  N            761
# 22             40.782242                  N           1102
# 23             40.720100                  N           1158
# 24             40.710327                  N           1481
# 25             40.780117                  N            464
# 26             40.727978                  N            361
# 27             40.713074                  N           1550
# 28             40.760380                  N           1075
# 29             40.735149                  N            606
# ...                  ...                ...            ...
# 583428         40.747627                  N            389
# 583429         40.607838                  N           2098
# 583430         40.755409                  N            533
# 583431         40.771690                  N           1033
# 583432         40.736012                  N            293
# 583433         40.711758                  N           1024
# 583434         40.673939                  N           2197
# 583435         40.688229                  N            787
# 583436         40.781021                  N            230
# 583437         40.749134                  N           1406
# 583438         40.760456                  N            745
# 583439         40.796577                  N            588
# 583440         40.793533                  N            700
# 583441         40.756023                  N            207
# 583442         40.755371                  N            239
# 583443         40.764240                  N            517
# 583444         40.751381                  N            662
# 583445         40.709663                  N            754
# 583446         40.663120                  N           1442
# 583447         40.758324                  N            591
# 583448         40.614571                  N           2261
# 583449         40.760883                  N            533
# 583450         40.736351                  N            631
# 583451         40.773384                  N            224
# 583452         40.738762                  N            156
# 583453         40.748905                  N            774
# 583454         40.751530                  N            294
# 583455         40.787312                  N            468
# 583456         40.783192                  N            419
# 583457         40.762466                  N            333
#
# [583458 rows x 11 columns]

# %%
#function to determine distance between pickup/dropoff
def find_distance (pickup_longitude,pickup_latitude,dropoff_longitude,dropoff_latitude):
    pickup_xy = (pickup_longitude,pickup_latitude)
    dropoff_xy = (dropoff_longitude,dropoff_latitude)
    drive_distance = distance(lonlat(*pickup_xy), lonlat(*dropoff_xy)).miles
    return drive_distance

# %%
df['distance'] = df.apply(lambda row: find_distance(row['pickup_longitude'], row['pickup_latitude'], row ['dropoff_longitude'], row['dropoff_latitude']), axis=1)
# Out:
# -----------------------------------------
# NameErrorTraceback (most recent call last)
# <ipython-input-11-b2090e3d4b09> in <module>()
# ----> 1 df['distance'] = df.apply(lambda row: find_distance(row['pickup_longitude'], row['pickup_latitude'], row ['dropoff_longitude'], row['dropoff_latitude']), axis=1)
#       2
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in apply(self, func, axis, broadcast, raw, reduce, result_type, args, **kwds)
#    6002                          args=args,
#    6003                          kwds=kwds)
# -> 6004         return op.get_result()
#    6005
#    6006     def applymap(self, func):
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/apply.py in get_result(self)
#     140             return self.apply_raw()
#     141
# --> 142         return self.apply_standard()
#     143
#     144     def apply_empty_result(self):
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/apply.py in apply_standard(self)
#     246
#     247         # compute the result using the series generator
# --> 248         self.apply_series_generator()
#     249
#     250         # wrap results
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/apply.py in apply_series_generator(self)
#     275             try:
#     276                 for i, v in enumerate(series_gen):
# --> 277                     results[i] = self.f(v)
#     278                     keys.append(v.name)
#     279             except Exception as e:
#
# <ipython-input-11-b2090e3d4b09> in <lambda>(row)
# ----> 1 df['distance'] = df.apply(lambda row: find_distance(row['pickup_longitude'], row['pickup_latitude'], row ['dropoff_longitude'], row['dropoff_latitude']), axis=1)
#       2
#
# <ipython-input-8-0c0b1b4c8cde> in find_distance(pickup_longitude, pickup_latitude, dropoff_longitude, dropoff_latitude)
#       3     pickup_xy = (pickup_longitude,pickup_latitude)
#       4     dropoff_xy = (dropoff_longitude,dropoff_latitude)
# ----> 5     drive_distance = distance(lonlat(*pickup_xy), lonlat(*dropoff_xy)).miles
#       6     return drive_distance
#
# NameError: ("name 'distance' is not defined", 'occurred at index 0')

# %%
df.head(5)
# Out:
#    Unnamed: 0         id  vendor_id      pickup_datetime     dropoff_datetime  \
# 0      583100  id3879397          1  2016-06-02 17:46:16  2016-06-02 18:22:26
# 1     1320440  id0701659          1  2016-03-02 10:07:11  2016-03-02 10:20:39
# 2      358078  id3093367          2  2016-02-17 17:18:27  2016-02-17 18:21:34
# 3     1118733  id0727316          2  2016-03-17 07:30:59  2016-03-17 07:42:18
# 4      110409  id2137873          2  2016-04-20 17:15:26  2016-04-20 18:01:57
#
#    passenger_count  pickup_longitude  pickup_latitude  dropoff_longitude  \
# 0                1        -73.990105        40.732841         -73.973244
# 1                1        -73.975693        40.759712         -73.988235
# 2                2        -73.781830        40.644772         -73.989960
# 3                1        -73.956200        40.778713         -73.976463
# 4                6        -73.789513        40.646938         -73.951851
#
#    dropoff_latitude store_and_fwd_flag  trip_duration   distance
# 0         40.782879                  N           2170   3.564261
# 1         40.753986                  N            808   0.767617
# 2         40.747150                  N           3787  13.014807
# 3         40.739731                  N            679   2.892396
# 4         40.809151                  N           2791  14.067818

# %%
df[df.passenger_count != 0] #drop rows where passenger count = 0
# Out:
#         Unnamed: 0         id  vendor_id      pickup_datetime  \
# 0           583100  id3879397          1  2016-06-02 17:46:16
# 1          1320440  id0701659          1  2016-03-02 10:07:11
# 2           358078  id3093367          2  2016-02-17 17:18:27
# 3          1118733  id0727316          2  2016-03-17 07:30:59
# 4           110409  id2137873          2  2016-04-20 17:15:26
# 5           851493  id0947345          1  2016-05-20 13:28:43
# 6           585211  id1719734          2  2016-03-30 20:27:43
# 7           252133  id1766631          1  2016-01-11 00:12:45
# 8           605202  id3271163          1  2016-03-19 01:10:52
# 9           482175  id1365294          2  2016-04-08 08:58:58
# 10         1001562  id3780207          1  2016-06-25 17:17:37
# 11         1173354  id2807877          2  2016-05-20 07:22:04
# 12          521167  id3987564          2  2016-02-23 23:34:52
# 13          536110  id3064301          2  2016-04-07 23:35:43
# 14           31606  id0040176          1  2016-03-10 13:09:10
# 15          883640  id2593602          1  2016-06-26 20:47:02
# 16          726758  id3907768          1  2016-02-14 08:23:52
# 17         1300909  id1224440          1  2016-06-30 00:45:22
# 18          956683  id3869128          2  2016-05-13 18:35:08
# 19          258418  id3435240          2  2016-05-28 02:16:30
# 20           24047  id3846053          2  2016-06-20 10:37:46
# 21         1236109  id1733720          2  2016-05-14 17:41:24
# 22          648965  id1404368          2  2016-03-05 09:56:16
# 583439                  N            588   2.107610
# 583440                  N            700   0.736365
# 583441                  N            207   0.692815
# 583442                  N            239   0.627715
# 583443                  N            517   1.647152
# 583444                  N            662   0.252319
# 583445                  N            754   2.067265
# 583446                  N           1442   8.130631
# 583447                  N            591   0.511784
# 583448                  N           2261  13.480321
# 583449                  N            533   1.036740
# 583450                  N            631   1.022878
# 583451                  N            224   0.351484
# 583452                  N            156   0.676535
# 583453                  N            774   0.715684
# 583454                  N            294   0.913448
# 583455                  N            468   2.000351
# 583456                  N            419   0.499488
# 583457                  N            333   0.678282
#
# [583426 rows x 13 columns]

# %%
df.vendor_id.unique()
# Out:
# array([1, 2])

# %%
#Groupby theme_name and calculate average price
grouped = df.groupby('vendor_id')['trip_duration','distance'].mean()
#Can be helpful to preview your intermediate transformations
grouped.head()
# Out:
#            trip_duration  distance
# vendor_id
# 1             850.245865  2.112493
# 2            1059.552372  2.160969

# %%
vendor1 = df[(df['vendor_id']==1)]
print(len(vendor1))
vendor2 = df[(df['vendor_id']==2)]
print(len(vendor2))
print(len(df))
# Out:
# 271132
# 312326
# 583458

# %%
df.store_and_fwd_flag.unique()
# Out:
# array(['N', 'Y'], dtype=object)

# %%
#convert string value to integer
store_and_fwd_dict = {'N' : 0, 'Y' : 1}
df['store_and_fwd_flag'] = df.store_and_fwd_flag.map(store_and_fwd_dict)
df.head()
# Out:
#    Unnamed: 0         id  vendor_id      pickup_datetime     dropoff_datetime  \
# 0      583100  id3879397          1  2016-06-02 17:46:16  2016-06-02 18:22:26
# 1     1320440  id0701659          1  2016-03-02 10:07:11  2016-03-02 10:20:39
# 2      358078  id3093367          2  2016-02-17 17:18:27  2016-02-17 18:21:34
# 3     1118733  id0727316          2  2016-03-17 07:30:59  2016-03-17 07:42:18
# 4      110409  id2137873          2  2016-04-20 17:15:26  2016-04-20 18:01:57
#
#    passenger_count  pickup_longitude  pickup_latitude  dropoff_longitude  \
# 0                1        -73.990105        40.732841         -73.973244
# 1                1        -73.975693        40.759712         -73.988235
# 2                2        -73.781830        40.644772         -73.989960
# 3                1        -73.956200        40.778713         -73.976463
# 4                6        -73.789513        40.646938         -73.951851
#
#    dropoff_latitude  store_and_fwd_flag  trip_duration   distance
# 0         40.782879                   0           2170   3.564261
# 1         40.753986                   0            808   0.767617
# 2         40.747150                   0           3787  13.014807
# 3         40.739731                   0            679   2.892396
# 4         40.809151                   0           2791  14.067818

# %%
#what is tore_and_fwd_flag?

store_n_vendor1 = df[(df['store_and_fwd_flag']==0)& (df['vendor_id']==1)]
store_n_vendor2 = df[(df['store_and_fwd_flag']==0)& (df['vendor_id']==2)]
print(len(store_n_vendor1))
print(len(store_n_vendor2))
store_y_vendor1 = df[(df['store_and_fwd_flag']==1)& (df['vendor_id']==1)]
store_y_vendor2 = df[(df['store_and_fwd_flag']==1)& (df['vendor_id']==2)]
print(len(store_y_vendor1))
print(len(store_y_vendor2))
print(len(df))
#vendor2 doesn't have any data where store_and_fwd_flag=Y??
# Out:
# 267860
# 312326
# 3272
# 0
# 583458

# %%
df = df[df.store_and_fwd_flag != 1]
len(df)
# Out:
# 580186

# %%
import datetime

#function to find day of week
def find_dayofweek (pickup_time):
    split_date = pickup_time.split()
    year, month, day = (int(x) for x in split_date[0].split('-'))    
    day_of_week = datetime.date(year, month, day).weekday()
    return day_of_week
# Out:
# 3

# %%
df['day_of_week'] = df.apply(lambda row: find_dayofweek(row['pickup_datetime']), axis=1)
df.head(5)
# Out:
#    Unnamed: 0         id  vendor_id      pickup_datetime     dropoff_datetime  \
# 0      583100  id3879397          1  2016-06-02 17:46:16  2016-06-02 18:22:26
# 1     1320440  id0701659          1  2016-03-02 10:07:11  2016-03-02 10:20:39
# 2      358078  id3093367          2  2016-02-17 17:18:27  2016-02-17 18:21:34
# 3     1118733  id0727316          2  2016-03-17 07:30:59  2016-03-17 07:42:18
# 4      110409  id2137873          2  2016-04-20 17:15:26  2016-04-20 18:01:57
#
#    passenger_count  pickup_longitude  pickup_latitude  dropoff_longitude  \
# 0                1        -73.990105        40.732841         -73.973244
# 1                1        -73.975693        40.759712         -73.988235
# 2                2        -73.781830        40.644772         -73.989960
# 3                1        -73.956200        40.778713         -73.976463
# 4                6        -73.789513        40.646938         -73.951851
#
#    dropoff_latitude  store_and_fwd_flag  trip_duration   distance  day_of_week
# 0         40.782879                   0           2170   3.564261            3
# 1         40.753986                   0            808   0.767617            2
# 2         40.747150                   0           3787  13.014807            2
# 3         40.739731                   0            679   2.892396            3
# 4         40.809151                   0           2791  14.067818            2

# %%
to_plot = df.groupby('day_of_week').trip_duration.mean()
to_plot.plot(kind='barh')

# %%
#calucate speed
def find_speed (duration, distance):
    duration_hr = duration/3600
    speed = distance/duration_hr
    return speed
df['speed'] = df.apply(lambda row: find_speed(row['trip_duration'], row['distance']), axis=1)
df.head(5)
# Out:
#    Unnamed: 0         id  vendor_id      pickup_datetime     dropoff_datetime  \
# 0      583100  id3879397          1  2016-06-02 17:46:16  2016-06-02 18:22:26
# 1     1320440  id0701659          1  2016-03-02 10:07:11  2016-03-02 10:20:39
# 2      358078  id3093367          2  2016-02-17 17:18:27  2016-02-17 18:21:34
# 3     1118733  id0727316          2  2016-03-17 07:30:59  2016-03-17 07:42:18
# 4      110409  id2137873          2  2016-04-20 17:15:26  2016-04-20 18:01:57
#
#    passenger_count  pickup_longitude  pickup_latitude  dropoff_longitude  \
# 0                1        -73.990105        40.732841         -73.973244
# 1                1        -73.975693        40.759712         -73.988235
# 2                2        -73.781830        40.644772         -73.989960
# 3                1        -73.956200        40.778713         -73.976463
# 4                6        -73.789513        40.646938         -73.951851
#
#    dropoff_latitude  store_and_fwd_flag  trip_duration   distance  \
# 0         40.782879                   0           2170   3.564261
# 1         40.753986                   0            808   0.767617
# 2         40.747150                   0           3787  13.014807
# 3         40.739731                   0            679   2.892396
# 4         40.809151                   0           2791  14.067818
#
#    day_of_week      speed
# 0            3   5.913060
# 1            2   3.420075
# 2            2  12.372143
# 3            3  15.335238
# 4            2  18.145520

# %%
to_plot = df.groupby('day_of_week').speed.mean()
to_plot.plot(kind='barh')

# %%
cols = ['vendor_id', 'trip_duration', 'distance', 'day_of_week', 'speed']

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'id', 'vendor_id', 'pickup_datetime', 'dropoff_datetime',
#        'passenger_count', 'pickup_longitude', 'pickup_latitude',
#        'dropoff_longitude', 'dropoff_latitude', 'store_and_fwd_flag',
#        'trip_duration', 'distance', 'day_of_week', 'speed'],
#       dtype='object')

# %%
df.shape
# Out:
# (580186, 15)

# %%
df.isnull().any()
# Out:
# Unnamed: 0            False
# id                    False
# vendor_id             False
# pickup_datetime       False
# dropoff_datetime      False
# passenger_count       False
# pickup_longitude      False
# pickup_latitude       False
# dropoff_longitude     False
# dropoff_latitude      False
# store_and_fwd_flag    False
# trip_duration         False
# distance              False
# day_of_week           False
# speed                 False
# dtype: bool

# %%
pd.plotting.scatter_matrix(df[["trip_duration", "speed", "distance", "day_of_week", "vendor_id"]]);
# Out:
# -----------------------------------------
# NameErrorTraceback (most recent call last)
# <ipython-input-1-1d05a4638625> in <module>()
# ----> 1 pd.plotting.scatter_matrix(df[["trip_duration", "speed", "distance", "day_of_week", "vendor_id"]]);
#
# NameError: name 'pd' is not defined

# %%
X = df.drop('trip_duration', axis=1)
y = df.trip_duration

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
# %matplotlib inline

# %%
ols = LinearRegression()
model_scores = {}
for col in X.columns:
    try:
        train_r2 = []
        test_r2 = []
        for i in range(3):
            X_train, X_test, y_train, y_test = train_test_split(X, y)
            ols.fit(np.array(X_train[col]).reshape(-1,1), y_train)
            train_r2.append(ols.score(np.array(X_train[col]).reshape(-1,1), y_train))
            test_r2.append(ols.score(np.array(X_test[col]).reshape(-1,1), y_test))
        model_scores[col] = (np.mean(train_r2), np.mean(test_r2))
    except:
        continue
        print("Couldn't perform regression using {}, probably not a numeric feature.".format(col))
        print("Top feature attributes:\n", df[col].value_counts(normalize=True)[:5])
model_scores = pd.DataFrame.from_dict(model_scores, orient='index')
model_scores.columns = ['Train_r2', 'Test_r2']
model_scores = model_scores.sort_values(by='Test_r2', ascending=False)
model_scores.head()
# Out:
# (0.0006375931683865558, 0.0008616800966303462)
#                   Train_r2   Test_r2
# distance          0.008733  0.009198
# vendor_id         0.000247  0.000919
# pickup_latitude   0.000763  0.000905
# speed             0.000638  0.000862
# dropoff_latitude  0.000535  0.000631

# %%
# Your code here
ols = LinearRegression()
model2_scores = {}
cur_feats = ['distance']
for iteration, col in enumerate(X.columns):
    try:
        train_r2 = []
        test_r2 = []
        feats = cur_feats + [col]
        for i in range(3):
            X_train, X_test, y_train, y_test = train_test_split(X, y)
            ols.fit(X_train[feats], y_train)
            train_r2.append(ols.score(X_train[feats], y_train))
            test_r2.append(ols.score(X_test[feats], y_test))
        model2_scores[col] = (np.mean(train_r2), np.mean(test_r2))
    except Exception as e:
        if iteration < 5:
            print(e)
        continue
#         print("Couldn't perform regression using {}, probably not a numeric feature.".format(col))
#         print("Top feature attributes:\n", df[col].value_counts(normalize=True)[:5])
model2_scores = pd.DataFrame.from_dict(model2_scores, orient='index')
model2_scores.columns = ['Train_r2', 'Test_r2']
model2_scores = model2_scores.sort_values(by='Test_r2', ascending=False)
model2_scores.head()
# Out:
# could not convert string to float: 'id1075199'
# could not convert string to float: '2016-03-28 20:42:50'
# could not convert string to float: '2016-03-11 16:28:59'
#                     Train_r2   Test_r2
# speed               0.012162  0.039928
# passenger_count     0.005813  0.025868
# store_and_fwd_flag  0.005875  0.025186
# distance            0.008433  0.016159
# pickup_latitude     0.011130  0.014749
